# %% [markdown]
# ## 기초데이터과학 (01분반)
#
# ## Programming assignment 06

# %% [markdown]
# ### 1. 월별 매출 분석을 시각화하세요 (Matplotlib)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 데이터
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sales = [1200, 1350, 1450, 1380, 1500, 1680, 
         1820, 1950, 1780, 1650, 1900, 2100]
costs = [800, 850, 900, 880, 920, 1000, 
         1050, 1100, 1020, 980, 1100, 1200]

# %% [markdown]
# #### 1-1. 선 그래프로 매출 추이를 시각화하세요.
# - plot() 함수를 사용하여 월별 매출(sales)과 비용(costs)을 하나의 선 그래프로 시각화하세요.
# - 매출은 파란색 실선으로, 비용은 빨간색 점선으로 표현하세요.
# - 각 데이터 포인트에 원형 마커를 추가하세요.
# - 제목은 "2024 Monthly Sales and Costs Trend", x축 레이블은 "Month", y축 레이블은 "Amount (10,000 KRW)"으로 설정하세요.
# - 범례를 표시하고, 그리드를 추가하세요.

# %%
# 선 그래프 그리기
graph_sales=plt.plot(months,sales,label='Sales',color='blue',linestyle='-',marker='o')
graph_costs=plt.plot(months,costs,label='Costs',color='red',linestyle='--',marker='o')

# 제목 및 레이블 설정
plt.title("2024 Monthly Sales and Costs Trend")
plt.xlabel("Month")
plt.ylabel("Amount (10,000 KRW)")

# 범례와 그리드 추가
plt.legend(loc='upper left')
plt.grid(True)

plt.show()

# %% [markdown]
# #### 1-2. 축 범위와 눈금을 설정하세요
# - 1-1에서 그린 그래프에 추가로 다음 설정을 적용하세요.
# - y축 범위를 500부터 2500까지로 설정하세요.
# - y축 눈금을 500, 1000, 1500, 2000, 2500으로 설정하세요.
# - 그래프를 'monthly_sales.png' 파일로 저장하세요.

# %%
# 선 그래프 그리기
graph_sales=plt.plot(months,sales,label='Sales',color='blue',linestyle='-',marker='o')
graph_costs=plt.plot(months,costs,label='Costs',color='red',linestyle='--',marker='o')

# 제목 및 레이블 설정
plt.title("2024 Monthly Sales and Costs Trend")
plt.xlabel("Month")
plt.ylabel("Amount (10,000 KRW)")

# 범례와 그리드 추가
plt.legend(loc='upper right')
plt.grid(True)

# y축 범위와 눈금 설정
plt.ylim(500,2500)
plt.yticks(list(range(500,2501,500)))

# 파일로 저장
plt.savefig('monthly_sales.png')

# %% [markdown]
# #### 1-3. 막대 그래프로 순이익을 시각화하세요.
# - 월별 순이익(Sales - Costs)을 계산하고, 막대 그래프로 시각화하세요.
# - 막대 색상은 초록색으로 설정하세요.
# - 제목은 "2024 Monthly Net Profit", x축 레이블은 "Month", y축 레이블은 "Net Profit (10,000 KRW)"으로 설정하세요.
# - x축 레이블을 읽기 쉽게 45도 회전시키세요.

# %%
# 순이익 계산
benefits=[a-b for a,b in zip(sales,costs)]

# 막대 그래프 그리기
plt.bar(months,benefits,color='green')

# 제목 및 레이블 설정
plt.title("2024 Monthly Net Profit")
plt.xlabel("Month")
plt.ylabel("Net Profit (10,000 KRW)")

# x축 레이블 회전
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### 2. 학생 성적 분포를 분석하세요. (Seaborn)

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 데이터 생성
np.random.seed(42)
students = pd.DataFrame({
    'Student_ID': range(1, 31),
    'Midterm': np.random.randint(50, 100, 30),
    'Final': np.random.randint(55, 100, 30),
    'Gender': np.random.choice(['Male', 'Female'], 30),
    'Study_Hours': np.random.randint(1, 8, 30)
})

# 데이터 확인
students.head()
# Out:
#    Student_ID  Midterm  Final  Gender  Study_Hours
# 0           1       88     81  Female            2
# 1           2       78     96  Female            7
# 2           3       64     82  Female            5
# 3           4       92     70  Female            2
# 4           5       57     69  Female            1

# %% [markdown]
# #### 2-1. 히스토그램과 밀도 분포 그래프를 그리세요.
#
# - 중간고사 점수의 분포를 히스토그램으로 시각화하세요.
# - bins=10으로 설정하고, kde=True로 설정하여 밀도 곡선도 함께 표시하세요.
# - 성별에 따라 다른 색상으로 구분하세요.
# - 제목을 "Midterm exam score distribution"으로 설정하세요.

# %%
# 히스토그램과 밀도 분포 그래프
sns.histplot(data=students, x='Midterm',bins=10, kde=True, hue='Gender')

# 제목 설정
plt.title('Midterm exam score distribution')

plt.show()

# %% [markdown]
# #### 2-2. 산점도와 회귀선을 그리세요.
#
# - 중간고사 점수(x축)와 기말고사 점수(y축)의 관계를 회귀선과 함께 시각화하세요.
# - 제목을 "Correlation between midterm and final exam scores"로 설정하세요.
# - x축 레이블은 "Midterm", y축 레이블은 "Final"로 설정하세요.

# %%
# 회귀선 포함 산점도
sns.regplot(data=students,x='Midterm',y='Final')

# 제목 및 레이블 설정
plt.title("Correlation between midterm and final exam scores")

plt.show()

# %% [markdown]
# #### 2-3. 조인트 그래프를 그리세요
#
# - 학습시간(x축)과 기말고사 점수(y축)의 관계를 조인트 그래프로 시각화하세요.
# - 산점도로 표현하세요.
# - 성별에 따라 색상을 구분하세요.

# %%
# 조인트 그래프
joint_1=sns.jointplot(data=students,x='Study_Hours',y='Final',hue='Gender')

plt.show()

# %% [markdown]
# ### 3. 제품 판매 데이터를 분석하세요. (Seaborn)

# %%
import seaborn as sns
import pandas as pd

# 데이터 생성
sales_data = pd.DataFrame({
    'Month': ['January', 'January', 'January', 'January', 'February', 'February', 'February', 'February', 'March', 'March', 'March', 'March'],
    'Product': ['Laptop', 'Tablet', 'Smartphone', 'Earbuds', 
            'Laptop', 'Tablet', 'Smartphone', 'Earbuds',
            'Laptop', 'Tablet', 'Smartphone', 'Earbuds'],
    'Sales': [45, 62, 128, 203, 52, 58, 145, 189, 48, 71, 156, 225],
    'Average_Price': [1200, 800, 900, 150, 1180, 780, 920, 145, 1150, 820, 910, 140]
})

# 데이터 확인
sales_data
# Out:
#        Month     Product  Sales  Average_Price
# 0    January      Laptop     45           1200
# 1    January      Tablet     62            800
# 2    January  Smartphone    128            900
# 3    January     Earbuds    203            150
# 4   February      Laptop     52           1180
# 5   February      Tablet     58            780
# 6   February  Smartphone    145            920
# 7   February     Earbuds    189            145
# 8      March      Laptop     48           1150
# 9      March      Tablet     71            820
# 10     March  Smartphone    156            910
# 11     March     Earbuds    225            140

# %% [markdown]
# #### 3-1. 막대 그래프로 제품별 평균 판매량 비교하세요.
#
# - 제품별 평균 판매량을 막대 그래프로 시각화하세요.
# - x축에 'Product', y축에 'Sales'을 설정하세요.
# - 월별로 다른 색상으로 구분하세요.
# - 제목을 "Average monthly sales by product"으로 설정하세요.

# %%
# 막대 그래프
sns.barplot(data=sales_data,x='Product',y='Sales',hue='Month')

# 제목 설정
plt.title("Average monthly sales by product")
plt.xlabel("Product")
plt.ylabel("Sales")

plt.show()

# %% [markdown]
# #### 3-2. 박스 그래프로 제품별 판매량 분포를 비교하세요.
#
# - 제품별 판매량의 분포를 박스 그래프로 시각화하세요.
# - x축에 'Product', y축에 'Sales'을 설정하세요.
# - 제목을 "Sales distribution by product"로 설정하세요.

# %%
# 박스 그래프
sns.boxplot(data=sales_data,x='Product',y='Sales')

# 제목 설정
plt.title("Sales distribution by product")

plt.show()

# %% [markdown]
# #### 3-3. 바이올린 그래프로 제품별 가격 분포를 비교하세요.
#
# - 제품별 평균가격의 분포를 바이올린 그래프로 시각화하시오.
# - x축에 'Product', y축에 'Average_Price'을 설정하시오.
# - 월별로 다른 색상으로 구분하시오.
# - 제목을 "Average price distribution by product"로 설정하시오.

# %%
# 바이올린 그래프
sns.violinplot(data=sales_data,x='Product',y='Average_Price',hue='Month')

# 제목 설정
plt.title("Average price distribution by product")

plt.show()

# %% [markdown]
# ### 4. 타이타닉 데이터를 종합적으로 분석하세요. (Seaborn)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# 타이타닉 데이터 로드
titanic = sns.load_dataset('titanic')

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #### 4-1. 등급별 생존자 수를 시각화하세요
#
# - 등급별 승객 수를 막대 그래프로 시각화하세요.
# - 생존 여부에 따라 다른 색상으로 구분하세요.
# - 제목을 "Number of survivors and deaths by grade"로 설정하세요.
# - x축 레이블을 "Grade", y축 레이블을 "Number of passengers"로 설정하세요.

# %%
# 카운트 플롯
sns.countplot(data=titanic,x='pclass',hue='survived')

# 제목 및 레이블 설정
plt.title("Number of survivors and deaths by grade")
plt.xlabel("Grade")
plt.ylabel("Number of passengers")

plt.show()

# %% [markdown]
# #### 4-2. 나이와 운임의 관계를 시각화하세요.
#
# - 나이와 운임(fare)의 관계를 산점도로 시각화하세요.
# - 생존 여부에 따라 다른 색상으로 구분하세요.
# - 등급에 따라 다른 마커 스타일을 적용하세요.
# - 제목을 "Relationship between age and fare"로 설정하세요.
# - x축 레이블을 "Age", y축 레이블을 "Fare"으로 설정하세요.

# %%
# 산점도
sns.scatterplot(data=titanic,x='age',y='fare',hue='survived',style='pclass')

# 제목 및 레이블 설정
plt.title("Relationship between age and fare")
plt.xlabel("Age")
plt.ylabel("Fare")

plt.show()

# %% [markdown]
# #### 4-3. 상관관계 히트맵을 그리세요.
#
# - 타이타닉 데이터에서 숫자형 변수들(survived, pclass, age, fare)만 선택하여 상관계수를 계산하세요(corr() 함수 사용, 검색 필요).
# - 상관계수 행렬을 히트맵으로 시각화하세요.
# - 상관계수 값을 표시하세요.
# - 소수점 둘째 자리까지 표시하세요.
# - 'coolwarm'으로 색상 맵을 설정하세요.
# - 제목을 "Correlation between variables"로 설정하세요.

# %%
# 숫자형 변수 선택 및 상관계수 계산


# 히트맵


# 제목 설정
